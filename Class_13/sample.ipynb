# %% [markdown]
# import pandas as pd

# %%
import pandas as pd
import numpy as np

# %%
lst = ["indore", "mumbai", "pune"]
sr = pd.Series(lst)

# %%
print(type(sr))
print(sr)
# Out:
# <class 'pandas.core.series.Series'>
# 0    indore
# 1    mumbai
# 2      pune
# dtype: object

# %%
lst2 = [1,3,4,2,5]
st = pd.Series(lst2)
print(type(st))
print(st)
# Out:
# <class 'pandas.core.series.Series'>
# 0    1
# 1    3
# 2    4
# 3    2
# 4    5
# dtype: int64

# %%
dict = { "a":1, "b":3, "c":34}
dsr = pd.Series(dict)
print(type(dsr))
print(dsr)
# Out:
# <class 'pandas.core.series.Series'>
# a     1
# b     3
# c    34
# dtype: int64

# %%
# arr = (1,2,3,44,5,66,7,8)
# asr = np.series(arr)
# print(type(asr))
# print(asr)

# %%
lt =[10,20,30,40,50]
srd = pd.Series(data = lt , dtype =bool)
print(srd)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %%
sd = pd.series([10,20,30,40,50])
print(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sd = pd.series([10,20,30,40,50])
#       2 print(s)
#
# AttributeError: module 'pandas' has no attribute 'series'
